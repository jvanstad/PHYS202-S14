# %% [markdown]
# ### Differentiation Exercises

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# (a) Write two functions called twoPtForwardDiff(x,y) and twoPtCenteredDiff(x,y) that take as arguments arrays of values x and y(x) and return the derivatives of y with respect to x. Make sure that the arrays returned by the function have the same shape as the input arrays.

# %%
def twoPtForwardDiff(x,y):
    #Subtracts the difference from current value from the one in front of it 
    #for both x and y and return change y/ change x. (Forward difference).
    #Use backwards difference for last point
    dydx=np.zeros(y.shape,float)
    dydx[0:-1]=(y[1:]-y[:-1])/(x[1:]-x[:-1])
    dydx[-1]=(y[-1]-y[-2])/(x[-1]-x[-2])
    return dydx
def twoPtCenteredDiff(x,y):
    #Takes the difference between point behind and point in front for y and x. 
    #returns change y/change x. Last point uses forward backwards difference. 
    #first uses forward diff.
    dydx=np.zeros(y.shape,float)
    dydx[1:-1]=(y[2:]-y[:-2])/(x[2:]-x[:-2])
    dydx[0]=(y[1]-y[0])/(x[1]-x[0])
    dydx[-1]=(y[-1]-y[-2])/(x[-1]-x[-2])
    return dydx

# %% [markdown]
# (b) Use your functions to take the derivative of the function y=8x4+3x over the range 0 <x< 10, with steps of 0.1. How do you know they work correctly? (Hint: compare to the analytical result).

# %%
x=np.arange(0.0,10.0,0.1)
y=8*(x**4)+3*x
dydxEx=32*(x**3)+3
dydx1=twoPtForwardDiff(x,y)
dydx2=twoPtCenteredDiff(x,y)
plt.plot(x,dydx1,label='Forward difference')
plt.plot(x,dydx2,label='Center difference')
plt.plot(x,dydxEx,label='Exact')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# (c) What is the accuracy of the results if you use a spacing of 0.01? (Plot the relative error)

# %%
x=np.arange(0.0,10.0,0.01)
y=8*(x**4)+3*x
dydx1=twoPtForwardDiff(x,y)
dydx2=twoPtCenteredDiff(x,y)

dydxEx=32*(x**3)+3
per1=100*abs(dydx1[1:]-dydxEx[1:])/dydxEx[1:]
per2=100*abs(dydx2[1:]-dydxEx[1:])/dydxEx[1:]

plt.semilogy(x[1:],per1,label="forward diff")
plt.semilogy(x[1:],per2,label="Center diff")
plt.legend(loc="upper right")

# %% [markdown]
# (d) For what minimum spacing is the 2pt-centered difference derivative accurate to 5 significant figures over its full range (excluding the last point)?

# %%
x=np.arange(0.0,10.0,0.006)
y=8*(x**4)+3*x
dydx2=twoPtCenteredDiff(x,y)

dydxEx=32*(x**3)+3
#SET COEFFICIENT TO 10000 SO THAT VALUES MUST BE BELOW 1.
per2=10000*abs(dydx2[1:]-dydxEx[1:])/dydxEx[1:]
plt.semilogy(x[1:],per2,label="Center diff")

# %% [markdown]
# 2)
#
# Numerical differentiation plays an important role in fast electronic signal processing in many experimental contexts, such as the data acquisition systems of high energy particle and nuclear physics. The data collected is often a series of fast time samples of energy deposited in a detector by a fast-moving charged particle. The sheer volume of data can be enormous, so some signal processing within the electronics chain is necessary to reduce the size of the collected dataset.
# Due to the stochastic nature of the particle interactions and the inherent noise in the readout electronics, these signals can be very noisy. Unfortunately, numerical differentiation can amplify these fluctuations. By choosing your differentiation algorithm carefully, you can minimize the impact of these fluctuations on the collected signals.
# Generate and plot an example of a noisy sinusoidally varying dataset with the following:

# %%
h=np.linspace(0,2*pi,100)
k=np.sin(x)+0.1*random.random(size=x.shape)

# %%
def FourPtCenteredDiff(x,y):
    dydx=np.zeros(y.shape,float)
    #formula for allowable Four point diff
    h=x[2]-x[1]
    dydx[2:-2]=(y[:-4]-8*y[1:-3]+8*y[3:-1]-y[4:])/(12*h)
    #Use center diff for second to last point
    dydx[1]=(y[2]-y[0])/(x[2]-x[0])
    dydx[-2]=(y[-1]-y[-3])/(x[-1]-x[-3])
    #Forward diff for first
    dydx[0]=(y[1]-y[0])/(x[1]-x[0])
    #Backward diff for last
    dydx[-1]=(y[-1]-y[-2])/(x[-1]-x[-2])
    return dydx
dydx4=FourPtCenteredDiff(h,k)

# %%
#PLOTS ON PLOTS
dydx5=FourPtCenteredDiff(x,y)
plt.plot(x,dydx5,label='4 pt Center difference')
plt.plot(x,dydxEx,label='Exact')
plt.legend(loc='upper left')
plt.show()

# %%
#Relative Error.
x=np.arange(0.0,10.0,0.01)
y=8*(x**4)+3*x
dydx45=FourPtCenteredDiff(x,y)

dydxEx=32*(x**3)+3
per2=100*abs(dydx45[1:]-dydxEx[1:])/dydxEx[1:]
plt.semilogy(x[1:],per2,label="4 pt. Center diff")

# %% [markdown]
# (b) Now plot the noisy sine function along with the derivatives computed analytically, using the lowest order forward finite difference method and the four-point centered difference. Your result should look something like the plot shown here:

# %%
#SOMETHING IS SCREWY WITH THE TWO PT DIFF. FIXXXXIITTTTT
def twoPtForwardD(x,y):
    #Subtracts the difference from current value from the one in front of it 
    #for both x and y and return change y/ change x. (Forward difference).
    #Use backwards difference for last point
    dydx=np.zeros(y.shape,float)
    dydx[0:-1]=np.diff(y)/np.diff(x)
    dydx[-1]=(y[-1]-y[-2])/(x[-1]-x[-2])
    return dydx

dydxF=twoPtForwardDiff(h,k)
dydx2pt=twoPtCenteredDiff(h,k)

plt.plot(h,dydx4,label='4 pt Center difference')
plt.plot(h,k,label='Exact')
plt.plot(h,dydx2pt,label='2 pt Center difference')
plt.plot(h,dydxF,label='Forward')
plt.legend(loc='upper left')
plt.ylabel("Noisy data and derivs")
plt.xlabel("x")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-c05a4c33304f> in <module>()
#       9     return dydx
#      10
# ---> 11 dydxF=twoPtForwardDiff(h,k)
#      12 dydx2pt=twoPtCenteredDiff(h,k)
#      13
#
# <ipython-input-2-249bb27a9459> in twoPtForwardDiff(x, y)
#       4     #Use backwards difference for last point
#       5     dydx=np.zeros(y.shape,float)
# ----> 6     dydx[0:-1]=(y[1:]-y[:-1])/(x[1:]-x[:-1])
#       7     dydx[-1]=(y[-1]-y[-2])/(x[-1]-x[-2])
#       8     return dydx
#
# ValueError: operands could not be broadcast together with shapes (1666) (99)

# %% [markdown]
# (c) Write your three differentiating functions to a file called Differentiators.py. Be sure to include meaningful docstrings that describe what the functions do. The docstrings should include enough information for someone to understand the differences between the algorithms. Test that the code works by importing the functions and calling them on y=8x4+3x. Plot the results from all three methods.

# %%
# %%file Differentiators.py
import numpy as np
def twoPtForwardDiff(x,y):
    #Subtracts the difference from current value from the one in front of it 
    #for both x and y and return change y/ change x. (Forward difference).
    #Use backwards difference for last point
    dydx=np.zeros(y.shape,float)
    dydx[0:-1]=(y[1:]-y[:-1])/(x[1:]-x[:-1])
    dydx[-1]=(y[-1]-y[-2])/(x[-1]-x[-2])
    return dydx
def twoPtCenteredDiff(x,y):
    #Takes the difference between point behind and point in front for y and x. 
    #returns change y/change x. Last point uses forward backwards difference. 
    #first uses forward diff.
    dydx=np.zeros(y.shape,float)
    dydx[1:-1]=(y[2:]-y[:-2])/(x[2:]-x[:-2])
    dydx[0]=(y[1]-y[0])/(x[1]-x[0])
    dydx[-1]=(y[-1]-y[-2])/(x[-1]-x[-2])
    return dydx
def FourPtCenteredDif(x,y):
    dydx=np.zeros(y.shape,float)
    #formula for allowable Four point diff
    h=x[2]-x[1]
    dydx[2:-2]=(y[:-4]-8*y[1:-3]+8*y[3:-1]-y[4:])/(12*h)
    #Use center diff for second to last point
    dydx[1]=(y[2]-y[0])/(x[2]-x[0])
    dydx[-2]=(y[-1]-y[-3])/(x[-1]-x[-3])
    #Forward diff for first
    dydx[0]=(y[1]-y[0])/(x[1]-x[0])
    #Backward diff for last
    dydx[-1]=(y[-1]-y[-2])/(x[-1]-x[-2])
    return dydx
# Out:
# Overwriting Differentiators.py

# %%
import Differentiators as DF

# %%
x=np.arange(0.0,10.0,0.1)
y=8*(x**4)+3*x
T=DF.twoPtForwardDiff(x,y)
C=DF.twoPtCenteredDiff(x,y)
F=DF.FourPtCenteredDif(x,y)
plt.plot(x,T, label="Two pt Forward")
plt.legend(loc='upper left')
plt.show()

# %%
plt.plot(x,C, label="Two pt Centered")
plt.legend(loc='upper left')
plt.show()

# %%
plt.plot(x,F, label= "Four pt Centered")
plt.legend(loc='upper left')
plt.show()

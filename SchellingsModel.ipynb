# %% [markdown]
# ## Schellings Model Final Project

# %%
import numpy as np
from random import randint
import matplotlib.pyplot as plt
from ipythonblocks import BlockGrid
from ipythonblocks import colors
from IPython.display import clear_output
from IPython.html import widgets 
from IPython.display import display
from IPython.html.widgets import interact, interactive

# %%
RED=(255,0,0)
WHITE=(255,255,255)
GREEN=(0,255,0)
def Board(N=50,comp=50, dens=80): 
#N for board size, comp=composition between X and O (ie X/(X+O)), dens=(X+O)/(N*N)
    board=BlockGrid(N,N,fill=(255,255,255)) #Create a board of white boxes
    Xs=int((N**2)*dens/100.*comp/100.) #number of "X's" orginally
    Os=int((N**2)*(dens/100.)*(1-(comp/100.) ))#number "O's" originally
    i=0
    while i<Os+1: 
        C=randint(0,N-1)
        R=randint(0,N-1)
        i=i+1
        if board[C,R].blue==255:  # .blue function is used bc green and red dont have blue values, but white does. SO if the random box is white function fills it red until number of O's is satisfied
             board[C,R]=(255,0,0)
        else:
            i=i-1 #If random box is not white, reiterate at the same number
    i=0
    while i <Xs+1: 
        C=randint(0,N-1) #Random interger value for the column value
        R=randint(0,N-1) #Random interger value for the row value
        i=i+1
        if board[C,R].blue==255: #same as above. Make sure random square is white and fill it green until number of X's is satisfied
            board[C,R]=(0,255,0)
        else:
            i=i-1
    return board
boardA=Board(50,50,65) #dimension of box, composition of red/green boxes, density of colored squares (80 out of 100 squares)
boardA.show()
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blockseaad21a0-cd79-40ad-9266-3c82ee221e8f td {border: 1px solid white;}</style><table id="blockseaad21a0-cd79-40ad-9266-3c82ee221e8f" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 2]&#10;Color: (0, 255, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 0);"></td><td title="Index: [0, 3]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 5]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;backgr
# ...

# %%
RED=(255,0,0)
WHITE=(255,255,255)
GREEN=(0,255,0)
def BUDDIES(row,col,N): #For a particular box, find the boxes around it
    lst=(row-1,col-1),(row-1,col),(row-1,col+1),(row,col-1),(row,col+1),(row+1,col-1),(row+1,col),(row+1,col+1) #append neighboring boxes positions to lst
    BUDS=[]
    for i in lst:
        if i[0]>=0 and i[1]>=0 and i[0]<N and i[1]<N:   #Ensure that the neighboring values are actually within the box (ie for sides and corners)
            BUDS.append(i)
    return BUDS

def Satisfied(board,thresh,row,col,N): #Tells if a particular box is satisfied within the current threshold conditions
    red, green,white=0.,0.,0.
    bud=BUDDIES(row,col,N) #find the neghboring sqaures surrounding the box in question
    for i in bud:
        if board[i].rgb==GREEN: #Finds the number of green neighboring green boxes
            green+=1
        if board[i].rgb==RED: #Finds the number of neighboring red boxes
            red+=1
        if board[i].rgb==WHITE: #Finds the number of neighboring white boxes
            white+=1
    thr=0
    if red+green==0:  #watch for divide by zero, account for all white neighboring sqaures, also if square is white it will be satisfied
        return True
    elif board[row,col].red==255 and board[row,col].blue!=255:
        thr=red/(red+green)
    elif board[row,col].green==255 and board[row,col].blue!=255:
        thr=green/(green+red)
    return thr*100>=thresh #returns True for a satisfied box and False if it fails to meet the threshold

# %%
def PullnPray(board, N=50,thr=60):
    """Complies a list of al the unsatisfied boxes and white boxes by sweeping through the from left to right and top to bottom.
    Randomly shuffles the list to account for moderately consistent density throughout board. Iterates through all of the unsatisfied green and red boxes and
    switches their position with one of a different color (white included). Returns the newly shifted board"""
    good=[] #gives list of all unsatisfied and white boxes 
    for i in range(N): #iterate through i row
        for k in range(N): #iterate through k columns
            if Satisfied(board,thr,i,k,N)==False or board[i,k].rgb==WHITE: 
                good.append((i,k)) #returns a tuple of the posititon
    
    super=[] #Make a new junk list of randomly ordered unsatisfied postions from super. 
    for i in range(len(good)): 
        length=len(good) # after an iteration the original ordered unsatisfied list will have a differnet value
        rand=randint(0,length-1) #gives a random interger for length of good
        super.append(good[rand]) #Append this position from randomly selecting from good
        good.remove(good[rand]) #Remove the value from the original list to avoid double counting
    b=1
    while b <len(super): #If ony one color of the box remains the loop will end, the boxes remain as is
        a=super[0] #start with first value of unsatisfied list
        c = super[b]
        if board[a].rgb!=board[c].rgb: #If the colors of the two boxes are different
            temp=board[a].rgb # Use temp variable to prevent from losing first color that is switched
            board[a].rgb=board[c].rgb #change the color of the first to the "other" box
            board[c].rgb=temp #change the color of the other box to the first box
            super.remove(a) #Remove box a from list
            super.remove(c) #Remove box c from list
            b=1 #Return the value of b to the second box in the unsatisfied list
        b+=1 #If super[b] is the same color, increase b by 1 to move to next potential box
    return board          
#boardA.show()
boardA= PullnPray(boardA,50,60)
boardA.show()
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksb1c53de5-7183-4ecf-ad9e-93a5863e48e5 td {border: 1px solid white;}</style><table id="blocksb1c53de5-7183-4ecf-ad9e-93a5863e48e5" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 255, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 0);"></td><td title="Index: [0, 2]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 3]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 4]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (0, 255, 0)" style="width: 20px; height: 20px;background
# ...

# %%
BLACK=(0,0,0)
BLUE=(0,0,255)
RED=(255,0,0)
WHITE=(255,255,255)
GREEN=(0,255,0)
N=50
M=N
COUNT=[]

def ClusterCorner(picture, N,M,xstart,ystart): #Clusters with diagonals included
    Count=1 #Counts the intial box that will be looked at
    queue = [(xstart,ystart)]
    if picture[xstart,ystart].rgb==RED:
        while queue:
            x,y,queue = queue[0][0], queue[0][1], queue[1:]
            picture[x,y].rgb = BLUE #Change red boxes to blue boxes in order to count clusters. Intial box will be blue 
            if x > 0 and picture[x-1,y].rgb == RED:
                picture[x-1,y].rgb = BLUE
                queue.append((x-1,y))
                Count+=1
            if x < (N-1) and picture[x+1,y].rgb == RED:
                picture[x+1,y].rgb = BLUE
                queue.append((x+1,y))
                Count+=1
            if y > 0 and picture[x,y-1].rgb == RED:
                picture[x,y-1].rgb = BLUE
                queue.append((x, y-1))
                Count+=1
            if y < (N-1) and picture[x,y+1].rgb == RED:
                picture[x,y+1].rgb = BLUE
                queue.append((x, y+1))
                Count+=1
            #New Clusters with Diagonals
            if x > 0 and y>0 and picture[x-1,y-1].rgb == RED:
                picture[x-1,y-1].rgb = BLUE
                queue.append((x-1,y-1))
                Count+=1
            if x < (N-1) and y<(N-1) and picture[x+1,y+1].rgb == RED:
                picture[x+1,y+1].rgb = BLUE
                queue.append((x+1,y+1))
                Count+=1
            if y > 0 and x<(N-1) and picture[x+1,y-1].rgb == RED:
                picture[x+1,y-1].rgb = BLUE
                queue.append((x+1, y-1))
                Count+=1
            if y < (N-1) and x>0 and picture[x-1,y+1].rgb == RED:
                picture[x-1,y+1].rgb = BLUE
                queue.append((x-1, y+1))
                Count+=1
    elif picture[xstart,ystart].rgb==GREEN:
        while queue:
            x,y,queue = queue[0][0], queue[0][1], queue[1:]
            picture[x,y].rgb = BLACK #Change green boxes to blackboxes in order to count clusters. Intial box will be black 
            if x > 0 and picture[x-1,y].rgb == GREEN:
                picture[x-1,y].rgb = BLACK
                queue.append((x-1,y))
                Count+=1
            if x < (N-1) and picture[x+1,y].rgb == GREEN:
                picture[x+1,y].rgb = BLACK
                queue.append((x+1,y))
                Count+=1
            if y > 0 and picture[x,y-1].rgb == GREEN:
                picture[x,y-1].rgb = BLACK
                queue.append((x, y-1))
                Count+=1
            if y < (N-1) and picture[x,y+1].rgb == GREEN:
                picture[x,y+1].rgb = BLACK
                queue.append((x, y+1)) 
                Count+=1
            ###NEW
            if x > 0 and y>0 and picture[x-1,y-1].rgb == GREEN:
                picture[x-1,y-1].rgb = BLACK
                queue.append((x-1,y-1))
                Count+=1
            if x < (N-1) and y<(N-1) and picture[x+1,y+1].rgb == GREEN:
                picture[x+1,y+1].rgb = BLACK
                queue.append((x+1,y+1))
                Count+=1
            if y > 0 and x<(N-1) and picture[x+1,y-1].rgb == GREEN:
                picture[x+1,y-1].rgb = BLACK
                queue.append((x+1, y-1))
                Count+=1
            if y < (N-1) and x>0 and picture[x-1,y+1].rgb == GREEN:
                picture[x-1,y+1].rgb = BLACK
                queue.append((x-1, y+1))
                Count+=1
    if Count>0:
        COUNT.append(Count)
       
def names(picture,fillfunc,N):
    """scan the image top to bottom and left to right using a nested loop.
    when red or green pixel is found, change it black or blue accordingly, increment the count, then call the fill
    function to fill in all the pixels connected to that one."""
    COUNT=[]
    xsize, ysize = N,N
    temp=BlockGrid(N,N,fill=(255,255,255))
    for i in range(N):
        for j in range(N):
            temp[i,j].rgb=picture[i,j].rgb
    result = 0
    for x in range(xsize):
        for y in range(ysize):
            if temp[x,y].rgb== GREEN:
                result += 1
                fillfunc(temp,xsize,ysize,x,y)
            if temp[x,y].rgb==RED:
                result += 1
                fillfunc(temp,xsize,ysize,x,y)
            
    return result,temp

# %%
#REMEMBER TO SET COUNT TO EMPTY LIST BEFORE RESTARTING COUNT=[]
COUNT=[]
boardA= PullnPray(boardA,50,40)
a,b=names(boardA,ClusterCorner,50)
print a
b.show()
print COUNT
# Out:
# 149
# ...

# %% [markdown]
# \begin{equation}
# <s> = \left(\frac{2}{(L^2(1-\rho))^2}\Sigma n^2\right)
# \end{equation}

# %%
#Coefficient of Segregation Calculation!
swell=np.zeros(len(COUNT))
for i in range(len(COUNT)):
    swell[i]=COUNT[i]
def s(N,dens,swell):
    f=(2.0/(((N**2)*(dens/100.))**2.0))*(swell**2).sum()
    return f
print s(50,85,swell) #dimension, density, count
# Out:
# 0.0772579653979

# %%
def GetValues(N, comp,dens,thr):
    boardA=Board(N,comp,dens) #dimension of box, composition of red/green boxes, density of colored squares (80 out of 100 squares)
    for i in range(10):
        boardA= PullnPray(boardA,N,thr) #board, dimesion of box, threshold
    names(boardA,ClusterCorner,N)
    swell=np.zeros(len(COUNT))
    for i in range(len(COUNT)):
        swell[i]=COUNT[i]
    lst.append(s(N,dens,swell)) #dimension, density, count

# %%
#Super time consuming code for compiling data.. Dont run
#Remember to account for first empty list
"""LST=[()]
for j in range(30):
    lst=[]
    for i in range(3):
        COUNT=[]
        GetValues(50,50,50,75)
    JJ=np.mean(lst)
    LST.append(JJ)
print lst
print LST"""
# Out:
# 'LST=[()]\nfor j in range(30):\n    lst=[]\n    for i in range(3):\n        COUNT=[]\n        GetValues(50,50,50,75)\n    JJ=np.mean(lst)\n    LST.append(JJ)\nprint lst\nprint LST'

# %%
D50T55=[0.14420565333333335, 0.11006634666666666, 0.12329557333333334, 0.10090325333333333, 0.089448960000000008, 0.11048874666666668, 0.13880320000000002, 0.12946773333333333, 0.1422173866666667, 0.11259904, 0.14382250666666666, 0.13213696, 0.11961429333333333, 0.10374826666666669, 0.098114560000000003, 0.10303402666666667, 0.12479402666666667, 0.10050389333333333, 0.10406912, 0.11305386666666667, 0.11850666666666666, 0.11346517333333334, 0.10870528, 0.11022506666666666, 0.11578965333333334, 0.10229845333333333, 0.10091605333333332, 0.12259754666666667, 0.11080106666666667, 0.13305941333333335, 0.12815189333333335, 0.14439167999999999, 0.096514560000000013, 0.10852096, 0.10066261333333333, 0.13725952, 0.11291818666666668, 0.13192533333333334, 0.14115498666666668, 0.15049216000000001]
D50T65=[0.092918613333333344, 0.11888384, 0.10697472000000001, 0.08539477333333334, 0.13766655999999999, 0.11051178666666668, 0.12509866666666666, 0.088274773333333334, 0.14821290666666667, 0.087945386666666667, 0.11136341333333333, 0.11861504, 0.13854720000000001, 0.094269439999999996, 0.10084181333333335, 0.10060629333333333, 0.10641322666666668, 0.14060629333333333, 0.11068757333333334, 0.090388479999999993, 0.11334229333333333, 0.10707456, 0.11200768, 0.085985279999999997, 0.11578453333333333, 0.11336533333333333, 0.090561706666666672, 0.094715733333333343, 0.11840341333333333, 0.08233472, 0.1209088, 0.10366890666666667, 0.10476629333333332, 0.12393386666666667, 0.10230528, 0.09018453333333333, 0.075925333333333331, 0.072715093333333342, 0.086996480000000001, 0.12543829333333334]
D85T55=[0.50855743483275662, 0.39797695040369091, 0.47670152710495955, 0.4072050565167244, 0.41910388927335634, 0.51741379469434834, 0.38968632987312574, 0.51345775317185693, 0.39424442906574392, 0.60058810611303348, 0.45567793310265281, 0.44659687197231834, 0.47022357554786626, 0.3411859930795848, 0.50797752249134953, 0.47918652825836222, 0.40259469434832756, 0.48801306574394471, 0.38827168627450975, 0.40716135640138412, 0.47132670818915806, 0.35359210149942327, 0.37923757324106111, 0.45349617531718572, 0.41771995386389849, 0.38493069434832755, 0.36862021683967705, 0.37180087658592847, 0.41940890426758942, 0.48744260207612461, 0.46776012918108423, 0.51574610380622843, 0.39074162860438294, 0.438388336793541, 0.37421353633217996, 0.4022577900807382, 0.5145372641291811, 0.49229213379469439, 0.37972063667820066, 0.47927924336793537, 0.32748305420991924, 0.45614711880046138, 0.34533632295271049, 0.50932011995386384, 0.43829562168396774, 0.4012394002306805, 0.56638538408304495, 0.46943372549019607, 0.36882956401384082, 0.42165355478662053]
n,b = np.histogram(D85T60,bins=50,range=(0.,1.))
m,c = np.histogram(D85T75,bins=50,range=(0.,1.))
n1,b1 = np.histogram(D85T65,bins=50,range=(0.,1.))
m1,c1 = np.histogram(D85T85,bins=50,range=(0.,1.))
plt.plot(b[:-1],n,label="T=60%")
plt.plot(c[:-1],m,label="T=75%")
plt.plot(b1[:-1],n1,label="T=65%")
plt.plot(c1[:-1],m1,label="T=85%")
plt.title("Normalized Segregation at Density of 85%", fontsize=20)
plt.legend(loc="best")
plt.xlabel('Segregation Coefficient <s>')
plt.ylabel('Frequency')
plt.show()

# %%
def Board(N=50,comp=50, dens=80): 
#N for board size, comp=composition between X and O (ie X/(X+O)), dens=(X+O)/(N*N)
    board=BlockGrid(N,N,fill=(255,255,255)) #Create a board of white boxes
    Xs=int((N**2)*dens/100.*comp/100.) #number of "X's" orginally
    Os=int((N**2)*(dens/100.)*(1-(comp/100.) ))#number "O's" originally
    i=0
    while i<Os+1: 
        C=randint(0,N-1)
        R=randint(0,N-1)
        i=i+1
        if board[C,R].blue==255:  # .blue function is used bc green and red dont have blue values, but white does. SO if the random box is white function fills it red until number of O's is satisfied
             board[C,R]=(255,0,0)
        else:
            i=i-1 #If random box is not white, reiterate at the same number
    i=0
    while i <Xs+1: 
        C=randint(0,N-1) #Random interger value for the column value
        R=randint(0,N-1) #Random interger value for the row value
        i=i+1
        if board[C,R].blue==255: #same as above. Make sure random square is white and fill it green until number of X's is satisfied
            board[C,R]=(0,255,0)
        else:
            i=i-1
    return board.show()
boardA = interact(Board,N=(0,100) , comp=(10.0,70.0),dens=(30,99))
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks639ed50e-713a-42c5-9d18-6cd0a36e9c07 td {border: 1px solid white;}</style><table id="blocks639ed50e-713a-42c5-9d18-6cd0a36e9c07" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 255, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 255, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 0);"></td><td title="Index: [0, 3]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 255, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 255, 0);"></td><td title="Index: [0, 5]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255,
# ...
